# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Q1: Apply Ordinal encoding.

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()
X = np.asarray(df['class']).reshape(-1,1)
encoder.fit_transform(X)
# Out:
# array([[2.],
#        [0.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [1.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [0.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [0.],
#        [0.],
#        [2.],
#        [0.],
#        [2.],
# ...

# %% [markdown]
# # Q2: Apply One hot encoding.

# %%
from sklearn.preprocessing import OneHotEncoder
# encoder = OneHotEncoder()
# X = np.asarray(df['embarked']).reshape(-1,1)
# df['embarked'] = pd.DataFrame(encoder.fit_transform(X))

ohe = OneHotEncoder()
transformed = ohe.fit_transform(df[['embarked']])
df[ohe.categories_[0]] = transformed.toarray()

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# # Q3: Apply Frequency Encoding.

# %%
class_freq = (df.groupby('class').size()) / len(df)
df['class_freq'] = df['class'].apply(lambda x : class_freq[x])
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# # Q4: Apply Binary Encoding.

# %%
import category_encoders as ce
binary_enc = ce.BinaryEncoder(cols=['embarked'])

# transform the data 
data_binary = binary_enc.fit_transform(df['embarked'])
data_binary
# Out:
#      embarked_0  embarked_1  embarked_2
# 0             0           0           1
# 1             0           1           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           0           1           0
# 890           0           1           1
#
# [891 rows x 3 columns]
